# %%
import ROOT as r
# Out:
# Welcome to JupyROOT 6.24/06

# %%
c1 = r.TCanvas()

func = r.TF1("f1", "exp(-x/[0]) * (1 + [1] * cos([2]*x + [3]))", 0, 650)
func.SetNpx(10000)
func.SetParameters(64, 0.2, 1, 2)
func.Draw()
c1.Draw()

# %%
c1 = r.TCanvas()

func = r.TF1("f1", "(x-1) * (4*x^2-5*x-5) * (1 - [0] * (-8*x^2+x+1) / (4*x^2-5*x-5) * cos([1]) )", 0, 1)
func.SetParameters(0.95, 1.5*r.TMath.Pi())
func.Draw()
c1.Draw()
